# %%
import torch
import nibabel as nib
import imageio
import matplotlib.pyplot as plt
import numpy

image1 = nib.load('data/IXI012-HH-1211-T1_fcm.nii.gz')
plt.imshow(image1.get_fdata()[:,200,:], cmap="gray")
plt.show()

image2 = nib.load('data/IXI012-HH-1211-T2_reg_fcm.nii.gz')
plt.imshow(image2.get_fdata()[:,200,:], cmap="gray")
plt.show()
